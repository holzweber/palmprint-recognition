# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
cudnn.benchmark = True

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1)),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize(224),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1)),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

#data_dir = './drive/MyDrive/Tongji'
data_dir = '../input/tongjipalmprint/TJ'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=500):
    train_lss, val_lss, train_acc,val_acc = [], [], [], []
    since = time.time() #starting time

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            #add to lists
            if phase == 'train':
              train_lss.append(float(epoch_loss))
              train_acc.append(float(epoch_acc))
            else:
              val_lss.append(float(epoch_loss))
              val_acc.append(float(epoch_acc))

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, train_lss, val_lss, train_acc,val_acc

# %%
model_ft = models.resnet18(pretrained=True)

num_ftrs = model_ft.fc.in_features

model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.00005)

# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=100, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
model_ft, train_lss, val_lss, train_acc,val_acc = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=500)
# Out:
# Epoch 0/499
# ----------
# train Loss: 6.1931 Acc: 0.0478
# val Loss: 5.3214 Acc: 0.1747
#
# Epoch 1/499
# ----------
# train Loss: 4.5309 Acc: 0.4918
# val Loss: 3.9118 Acc: 0.5160
#
# Epoch 2/499
# ----------
# train Loss: 2.9332 Acc: 0.9115
# val Loss: 2.5206 Acc: 0.7682
#
# Epoch 3/499
# ----------
# train Loss: 1.4856 Acc: 0.9923
# val Loss: 1.4868 Acc: 0.8902
#
# Epoch 4/499
# ----------
# train Loss: 0.6195 Acc: 0.9987
# val Loss: 0.9396 Acc: 0.9270
#
# Epoch 5/499
# ----------
# train Loss: 0.2531 Acc: 1.0000
# val Loss: 0.6867 Acc: 0.9397
#
# Epoch 6/499
# ----------
# train Loss: 0.1201 Acc: 1.0000
# val Loss: 0.5151 Acc: 0.9537
#
# Epoch 7/499
# ----------
# train Loss: 0.0628 Acc: 0.9997
# val Loss: 0.4551 Acc: 0.9538
#
# Epoch 8/499
# ----------
# train Loss: 0.0344 Acc: 1.0000
# val Loss: 0.3465 Acc: 0.9635
#
# Epoch 9/499
# ----------
# train Loss: 0.0256 Acc: 1.0000
# val Loss: 0.3464 Acc: 0.9522
#
# Epoch 10/499
# ----------
# train Loss: 0.0228 Acc: 1.0000
# val Loss: 0.2900 Acc: 0.9575
#
# Epoch 11/499
# ----------
# train Loss: 0.0123 Acc: 0.9998
# val Loss: 0.2761 Acc: 0.9612
#
# Epoch 12/499
# ----------
# train Loss: 0.0058 Acc: 1.0000
# val Loss: 0.1904 Acc: 0.9703
#
# Epoch 13/499
# ----------
# train Loss: 0.0171 Acc: 0.9995
# val Loss: 0.2021 Acc: 0.9682
#
# Epoch 14/499
# ----------
# train Loss: 0.0037 Acc: 1.0000
# val Loss: 0.1849 Acc: 0.9652
#
# Epoch 15/499
# ----------
# train Loss: 0.0046 Acc: 1.0000
# val Loss: 0.1666 Acc: 0.9717
#
# Epoch 16/499
# ----------
# train Loss: 0.0026 Acc: 1.0000
# val Loss: 0.1998 Acc: 0.9623
#
# Epoch 17/499
# ----------
# train Loss: 0.0078 Acc: 0.9997
# val Loss: 0.4671 Acc: 0.9098
#
# Epoch 18/499
# ----------
# train Loss: 0.0052 Acc: 0.9998
# val Loss: 0.1410 Acc: 0.9768
#
# Epoch 19/499
# ----------
# train Loss: 0.0015 Acc: 1.0000
# val Loss: 0.1363 Acc: 0.9743
#
# Epoch 20/499
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.1162 Acc: 0.9790
#
# Epoch 21/499
# ----------
# train Loss: 0.0134 Acc: 0.9990
# val Loss: 0.1788 Acc: 0.9633
#
# Epoch 22/499
# ----------
# train Loss: 0.0018 Acc: 1.0000
# val Loss: 0.1583 Acc: 0.9652
#
# Epoch 23/499
# ----------
# train Loss: 0.0062 Acc: 0.9995
# val Loss: 0.3743 Acc: 0.9217
#
# Epoch 24/499
# ----------
# train Loss: 0.0036 Acc: 1.0000
# val Loss: 0.1433 Acc: 0.9692
#
# Epoch 25/499
# ----------
# train Loss: 0.0071 Acc: 0.9993
# val Loss: 0.1745 Acc: 0.9602
#
# Epoch 26/499
# ----------
# train Loss: 0.0021 Acc: 0.9998
# val Loss: 0.3038 Acc: 0.9275
#
# Epoch 27/499
# ----------
# train Loss: 0.0056 Acc: 0.9997
# val Loss: 0.2042 Acc: 0.9542
#
# Epoch 28/499
# ----------
# train Loss: 0.0031 Acc: 0.9998
# val Loss: 0.1833 Acc: 0.9590
#
# Epoch 29/499
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.1354 Acc: 0.9688
#
# Epoch 30/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1137 Acc: 0.9753
#
# Epoch 31/499
# ----------
# train Loss: 0.0066 Acc: 0.9995
# val Loss: 0.1930 Acc: 0.9542
#
# Epoch 32/499
# ----------
# train Loss: 0.0028 Acc: 0.9998
# val Loss: 0.1521 Acc: 0.9660
#
# Epoch 33/499
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.1246 Acc: 0.9697
#
# Epoch 34/499
# ----------
# train Loss: 0.0027 Acc: 0.9998
# val Loss: 0.4500 Acc: 0.8900
#
# Epoch 35/499
# ----------
# train Loss: 0.0078 Acc: 0.9992
# val Loss: 0.1735 Acc: 0.9552
#
# Epoch 36/499
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.1401 Acc: 0.9672
#
# Epoch 37/499
# ----------
# train Loss: 0.0023 Acc: 0.9998
# val Loss: 0.1923 Acc: 0.9508
#
# Epoch 38/499
# ----------
# train Loss: 0.0068 Acc: 0.9992
# val Loss: 0.2449 Acc: 0.9392
#
# Epoch 39/499
# ----------
# train Loss: 0.0019 Acc: 1.0000
# val Loss: 0.1835 Acc: 0.9582
#
# Epoch 40/499
# ----------
# train Loss: 0.0015 Acc: 0.9998
# val Loss: 0.1785 Acc: 0.9562
#
# Epoch 41/499
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.1607 Acc: 0.9605
#
# Epoch 42/499
# ----------
# train Loss: 0.0065 Acc: 0.9992
# val Loss: 0.2093 Acc: 0.9470
#
# Epoch 43/499
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.1924 Acc: 0.9500
#
# Epoch 44/499
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.1558 Acc: 0.9602
#
# Epoch 45/499
# ----------
# train Loss: 0.0058 Acc: 0.9990
# val Loss: 0.3849 Acc: 0.9083
#
# Epoch 46/499
# ----------
# train Loss: 0.0024 Acc: 1.0000
# val Loss: 0.1656 Acc: 0.9577
#
# Epoch 47/499
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.1970 Acc: 0.9475
#
# Epoch 48/499
# ----------
# train Loss: 0.0053 Acc: 0.9992
# val Loss: 0.1803 Acc: 0.9523
#
# Epoch 49/499
# ----------
# train Loss: 0.0014 Acc: 1.0000
# val Loss: 0.1732 Acc: 0.9533
#
# Epoch 50/499
# ----------
# train Loss: 0.0037 Acc: 0.9993
# val Loss: 0.2088 Acc: 0.9450
#
# Epoch 51/499
# ----------
# train Loss: 0.0036 Acc: 0.9995
# val Loss: 0.2157 Acc: 0.9462
#
# Epoch 52/499
# ----------
# train Loss: 0.0025 Acc: 0.9998
# val Loss: 0.1516 Acc: 0.9608
#
# Epoch 53/499
# ----------
# train Loss: 0.0045 Acc: 0.9993
# val Loss: 0.1987 Acc: 0.9538
#
# Epoch 54/499
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.1534 Acc: 0.9575
#
# Epoch 55/499
# ----------
# train Loss: 0.0078 Acc: 0.9987
# val Loss: 0.2661 Acc: 0.9290
#
# Epoch 56/499
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.1940 Acc: 0.9490
#
# Epoch 57/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1573 Acc: 0.9552
#
# Epoch 58/499
# ----------
# train Loss: 0.0087 Acc: 0.9987
# val Loss: 0.2560 Acc: 0.9353
#
# Epoch 59/499
# ----------
# train Loss: 0.0023 Acc: 0.9997
# val Loss: 0.1999 Acc: 0.9478
#
# Epoch 60/499
# ----------
# train Loss: 0.0031 Acc: 0.9993
# val Loss: 0.2892 Acc: 0.9265
#
# Epoch 61/499
# ----------
# train Loss: 0.0029 Acc: 0.9998
# val Loss: 0.1797 Acc: 0.9535
#
# Epoch 62/499
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.2277 Acc: 0.9333
#
# Epoch 63/499
# ----------
# train Loss: 0.0033 Acc: 0.9995
# val Loss: 0.2537 Acc: 0.9355
#
# Epoch 64/499
# ----------
# train Loss: 0.0066 Acc: 0.9988
# val Loss: 0.2723 Acc: 0.9313
#
# Epoch 65/499
# ----------
# train Loss: 0.0036 Acc: 0.9998
# val Loss: 0.2115 Acc: 0.9502
#
# Epoch 66/499
# ----------
# train Loss: 0.0021 Acc: 0.9997
# val Loss: 0.1763 Acc: 0.9550
#
# Epoch 67/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1534 Acc: 0.9583
#
# Epoch 68/499
# ----------
# train Loss: 0.0037 Acc: 0.9995
# val Loss: 0.2058 Acc: 0.9475
#
# Epoch 69/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1683 Acc: 0.9543
#
# Epoch 70/499
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.1495 Acc: 0.9597
#
# Epoch 71/499
# ----------
# train Loss: 0.0043 Acc: 0.9993
# val Loss: 0.1863 Acc: 0.9503
#
# Epoch 72/499
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.1565 Acc: 0.9598
#
# Epoch 73/499
# ----------
# train Loss: 0.0064 Acc: 0.9987
# val Loss: 0.2723 Acc: 0.9298
#
# Epoch 74/499
# ----------
# train Loss: 0.0048 Acc: 0.9993
# val Loss: 0.2091 Acc: 0.9450
#
# Epoch 75/499
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.1945 Acc: 0.9485
#
# Epoch 76/499
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.2909 Acc: 0.9252
#
# Epoch 77/499
# ----------
# train Loss: 0.0041 Acc: 0.9993
# val Loss: 0.2014 Acc: 0.9468
#
# Epoch 78/499
# ----------
# train Loss: 0.0014 Acc: 0.9998
# val Loss: 0.2497 Acc: 0.9342
#
# Epoch 79/499
# ----------
# train Loss: 0.0024 Acc: 0.9997
# val Loss: 0.1646 Acc: 0.9543
#
# Epoch 80/499
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.1308 Acc: 0.9648
#
# Epoch 81/499
# ----------
# train Loss: 0.0019 Acc: 0.9997
# val Loss: 0.2798 Acc: 0.9332
#
# Epoch 82/499
# ----------
# train Loss: 0.0054 Acc: 0.9997
# val Loss: 0.1923 Acc: 0.9507
#
# Epoch 83/499
# ----------
# train Loss: 0.0034 Acc: 0.9992
# val Loss: 0.1684 Acc: 0.9537
#
# Epoch 84/499
# ----------
# train Loss: 0.0049 Acc: 0.9983
# val Loss: 0.2499 Acc: 0.9375
#
# Epoch 85/499
# ----------
# train Loss: 0.0024 Acc: 0.9997
# val Loss: 0.1883 Acc: 0.9527
#
# Epoch 86/499
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.1444 Acc: 0.9605
#
# Epoch 87/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1644 Acc: 0.9593
#
# Epoch 88/499
# ----------
# train Loss: 0.0014 Acc: 0.9998
# val Loss: 0.2191 Acc: 0.9422
#
# Epoch 89/499
# ----------
# train Loss: 0.0033 Acc: 0.9992
# val Loss: 0.1891 Acc: 0.9522
#
# Epoch 90/499
# ----------
# train Loss: 0.0014 Acc: 0.9998
# val Loss: 0.2101 Acc: 0.9460
#
# Epoch 91/499
# ----------
# train Loss: 0.0009 Acc: 0.9998
# val Loss: 0.1760 Acc: 0.9537
#
# Epoch 92/499
# ----------
# train Loss: 0.0019 Acc: 0.9997
# val Loss: 0.3496 Acc: 0.9148
#
# Epoch 93/499
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.1689 Acc: 0.9562
#
# Epoch 94/499
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.1612 Acc: 0.9613
#
# Epoch 95/499
# ----------
# train Loss: 0.0054 Acc: 0.9988
# val Loss: 0.1834 Acc: 0.9560
#
# Epoch 96/499
# ----------
# train Loss: 0.0010 Acc: 0.9998
# val Loss: 0.1668 Acc: 0.9593
#
# Epoch 97/499
# ----------
# train Loss: 0.0040 Acc: 0.9988
# val Loss: 0.2467 Acc: 0.9333
#
# Epoch 98/499
# ----------
# train Loss: 0.0022 Acc: 0.9995
# val Loss: 0.1809 Acc: 0.9472
#
# Epoch 99/499
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1794 Acc: 0.9505
#
# Epoch 100/499
# ----------
# train Loss: 0.0007 Acc: 0.9998
# val Loss: 0.1624 Acc: 0.9545
#
# Epoch 101/499
# ----------
# train Loss: 0.0008 Acc: 0.9998
# val Loss: 0.1447 Acc: 0.9607
#
# Epoch 102/499
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.1503 Acc: 0.9572
#
# Epoch 103/499
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.1453 Acc: 0.9598
#
# Epoch 104/499
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.1439 Acc: 0.9600
#
# Epoch 105/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1323 Acc: 0.9632
#
# Epoch 106/499
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.1171 Acc: 0.9677
#
# Epoch 107/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1228 Acc: 0.9648
#
# Epoch 108/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1068 Acc: 0.9695
#
# Epoch 109/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1096 Acc: 0.9693
#
# Epoch 110/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1087 Acc: 0.9698
#
# Epoch 111/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.1074 Acc: 0.9715
#
# Epoch 112/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.1013 Acc: 0.9727
#
# Epoch 113/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0900 Acc: 0.9760
#
# Epoch 114/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0956 Acc: 0.9727
#
# Epoch 115/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0959 Acc: 0.9728
#
# Epoch 116/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0874 Acc: 0.9755
#
# Epoch 117/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0929 Acc: 0.9733
#
# Epoch 118/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0833 Acc: 0.9758
#
# Epoch 119/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0921 Acc: 0.9753
#
# Epoch 120/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0822 Acc: 0.9763
#
# Epoch 121/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0865 Acc: 0.9752
#
# Epoch 122/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0887 Acc: 0.9755
#
# Epoch 123/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0865 Acc: 0.9738
#
# Epoch 124/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0862 Acc: 0.9748
#
# Epoch 125/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0851 Acc: 0.9750
#
# Epoch 126/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0807 Acc: 0.9770
#
# Epoch 127/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0777 Acc: 0.9783
#
# Epoch 128/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0732 Acc: 0.9783
#
# Epoch 129/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0848 Acc: 0.9763
#
# Epoch 130/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0764 Acc: 0.9797
#
# Epoch 131/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0781 Acc: 0.9788
#
# Epoch 132/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0823 Acc: 0.9783
#
# Epoch 133/499
# ----------
# train Loss: 0.0005 Acc: 0.9998
# val Loss: 0.0715 Acc: 0.9797
#
# Epoch 134/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0760 Acc: 0.9790
#
# Epoch 135/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0690 Acc: 0.9805
#
# Epoch 136/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0686 Acc: 0.9807
#
# Epoch 137/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0625 Acc: 0.9825
#
# Epoch 138/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0746 Acc: 0.9798
#
# Epoch 139/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0692 Acc: 0.9803
#
# Epoch 140/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0731 Acc: 0.9793
#
# Epoch 141/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0716 Acc: 0.9797
#
# Epoch 142/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0702 Acc: 0.9797
#
# Epoch 143/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0736 Acc: 0.9778
#
# Epoch 144/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0661 Acc: 0.9813
#
# Epoch 145/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0644 Acc: 0.9807
#
# Epoch 146/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0679 Acc: 0.9805
#
# Epoch 147/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0735 Acc: 0.9793
#
# Epoch 148/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0671 Acc: 0.9795
#
# Epoch 149/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0780 Acc: 0.9793
#
# Epoch 150/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0701 Acc: 0.9787
#
# Epoch 151/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0707 Acc: 0.9800
#
# Epoch 152/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0688 Acc: 0.9787
#
# Epoch 153/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0660 Acc: 0.9793
#
# Epoch 154/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0664 Acc: 0.9787
#
# Epoch 155/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0648 Acc: 0.9807
#
# Epoch 156/499
# ----------
# train Loss: 0.0002 Acc: 0.9998
# val Loss: 0.0742 Acc: 0.9778
#
# Epoch 157/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0704 Acc: 0.9792
#
# Epoch 158/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0760 Acc: 0.9777
#
# Epoch 159/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0742 Acc: 0.9785
#
# Epoch 160/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0735 Acc: 0.9782
#
# Epoch 161/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0716 Acc: 0.9792
#
# Epoch 162/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0720 Acc: 0.9785
#
# Epoch 163/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0710 Acc: 0.9797
#
# Epoch 164/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0700 Acc: 0.9798
#
# Epoch 165/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0716 Acc: 0.9783
#
# Epoch 166/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0730 Acc: 0.9785
#
# Epoch 167/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0732 Acc: 0.9785
#
# Epoch 168/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0624 Acc: 0.9808
#
# Epoch 169/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0717 Acc: 0.9775
#
# Epoch 170/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0645 Acc: 0.9808
#
# Epoch 171/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0726 Acc: 0.9790
#
# Epoch 172/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0634 Acc: 0.9823
#
# Epoch 173/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0701 Acc: 0.9792
#
# Epoch 174/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0667 Acc: 0.9797
#
# Epoch 175/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0702 Acc: 0.9792
#
# Epoch 176/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0696 Acc: 0.9785
#
# Epoch 177/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0638 Acc: 0.9807
#
# Epoch 178/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0700 Acc: 0.9803
#
# Epoch 179/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0610 Acc: 0.9810
#
# Epoch 180/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0673 Acc: 0.9807
#
# Epoch 181/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0640 Acc: 0.9798
#
# Epoch 182/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0593 Acc: 0.9817
#
# Epoch 183/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0630 Acc: 0.9817
#
# Epoch 184/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0618 Acc: 0.9818
#
# Epoch 185/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0609 Acc: 0.9805
#
# Epoch 186/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0590 Acc: 0.9823
#
# Epoch 187/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0640 Acc: 0.9805
#
# Epoch 188/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0623 Acc: 0.9808
#
# Epoch 189/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9838
#
# Epoch 190/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0653 Acc: 0.9808
#
# Epoch 191/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0645 Acc: 0.9823
#
# Epoch 192/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0663 Acc: 0.9810
#
# Epoch 193/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0645 Acc: 0.9808
#
# Epoch 194/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0624 Acc: 0.9825
#
# Epoch 195/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0571 Acc: 0.9835
#
# Epoch 196/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0633 Acc: 0.9813
#
# Epoch 197/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0625 Acc: 0.9802
#
# Epoch 198/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0601 Acc: 0.9827
#
# Epoch 199/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9835
#
# Epoch 200/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0541 Acc: 0.9835
#
# Epoch 201/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0548 Acc: 0.9842
#
# Epoch 202/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0612 Acc: 0.9817
#
# Epoch 203/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0578 Acc: 0.9838
#
# Epoch 204/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0608 Acc: 0.9823
#
# Epoch 205/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9847
#
# Epoch 206/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0562 Acc: 0.9837
#
# Epoch 207/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0506 Acc: 0.9857
#
# Epoch 208/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0546 Acc: 0.9838
#
# Epoch 209/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0609 Acc: 0.9817
#
# Epoch 210/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0573 Acc: 0.9837
#
# Epoch 211/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0586 Acc: 0.9825
#
# Epoch 212/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0616 Acc: 0.9815
#
# Epoch 213/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0545 Acc: 0.9827
#
# Epoch 214/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9822
#
# Epoch 215/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0601 Acc: 0.9815
#
# Epoch 216/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0533 Acc: 0.9835
#
# Epoch 217/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0518 Acc: 0.9850
#
# Epoch 218/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9835
#
# Epoch 219/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0611 Acc: 0.9820
#
# Epoch 220/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0572 Acc: 0.9822
#
# Epoch 221/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0536 Acc: 0.9847
#
# Epoch 222/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0592 Acc: 0.9828
#
# Epoch 223/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9855
#
# Epoch 224/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0524 Acc: 0.9850
#
# Epoch 225/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0548 Acc: 0.9837
#
# Epoch 226/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0555 Acc: 0.9830
#
# Epoch 227/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0586 Acc: 0.9828
#
# Epoch 228/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0590 Acc: 0.9832
#
# Epoch 229/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0596 Acc: 0.9833
#
# Epoch 230/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0546 Acc: 0.9833
#
# Epoch 231/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0600 Acc: 0.9832
#
# Epoch 232/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0568 Acc: 0.9838
#
# Epoch 233/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0514 Acc: 0.9845
#
# Epoch 234/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0576 Acc: 0.9838
#
# Epoch 235/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9827
#
# Epoch 236/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9840
#
# Epoch 237/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9832
#
# Epoch 238/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0583 Acc: 0.9840
#
# Epoch 239/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0587 Acc: 0.9823
#
# Epoch 240/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0552 Acc: 0.9837
#
# Epoch 241/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9825
#
# Epoch 242/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0562 Acc: 0.9827
#
# Epoch 243/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0542 Acc: 0.9838
#
# Epoch 244/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0532 Acc: 0.9843
#
# Epoch 245/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0542 Acc: 0.9840
#
# Epoch 246/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0494 Acc: 0.9852
#
# Epoch 247/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0551 Acc: 0.9838
#
# Epoch 248/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0511 Acc: 0.9845
#
# Epoch 249/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0530 Acc: 0.9838
#
# Epoch 250/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0518 Acc: 0.9847
#
# Epoch 251/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0555 Acc: 0.9842
#
# Epoch 252/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0487 Acc: 0.9857
#
# Epoch 253/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0594 Acc: 0.9833
#
# Epoch 254/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9833
#
# Epoch 255/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0567 Acc: 0.9840
#
# Epoch 256/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0576 Acc: 0.9828
#
# Epoch 257/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0538 Acc: 0.9840
#
# Epoch 258/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9832
#
# Epoch 259/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0530 Acc: 0.9843
#
# Epoch 260/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0510 Acc: 0.9855
#
# Epoch 261/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9828
#
# Epoch 262/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0533 Acc: 0.9835
#
# Epoch 263/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0521 Acc: 0.9845
#
# Epoch 264/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0524 Acc: 0.9827
#
# Epoch 265/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0560 Acc: 0.9833
#
# Epoch 266/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0555 Acc: 0.9830
#
# Epoch 267/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0550 Acc: 0.9832
#
# Epoch 268/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0585 Acc: 0.9832
#
# Epoch 269/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0552 Acc: 0.9837
#
# Epoch 270/499
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9833
#
# Epoch 271/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0539 Acc: 0.9825
#
# Epoch 272/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0536 Acc: 0.9820
#
# Epoch 273/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0528 Acc: 0.9838
#
# Epoch 274/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0529 Acc: 0.9840
#
# Epoch 275/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9830
#
# Epoch 276/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0620 Acc: 0.9813
#
# Epoch 277/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0569 Acc: 0.9822
#
# Epoch 278/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0564 Acc: 0.9833
#
# Epoch 279/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9837
#
# Epoch 280/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9835
#
# Epoch 281/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0551 Acc: 0.9842
#
# Epoch 282/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0532 Acc: 0.9837
#
# Epoch 283/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0537 Acc: 0.9835
#
# Epoch 284/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9840
#
# Epoch 285/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0477 Acc: 0.9848
#
# Epoch 286/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0536 Acc: 0.9847
#
# Epoch 287/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0532 Acc: 0.9835
#
# Epoch 288/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0521 Acc: 0.9842
#
# Epoch 289/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0559 Acc: 0.9835
#
# Epoch 290/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0492 Acc: 0.9847
#
# Epoch 291/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0508 Acc: 0.9845
#
# Epoch 292/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9837
#
# Epoch 293/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0514 Acc: 0.9842
#
# Epoch 294/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0507 Acc: 0.9853
#
# Epoch 295/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9850
#
# Epoch 296/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0516 Acc: 0.9850
#
# Epoch 297/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0509 Acc: 0.9848
#
# Epoch 298/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0562 Acc: 0.9833
#
# Epoch 299/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0533 Acc: 0.9833
#
# Epoch 300/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0524 Acc: 0.9847
#
# Epoch 301/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0537 Acc: 0.9835
#
# Epoch 302/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9857
#
# Epoch 303/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9838
#
# Epoch 304/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0529 Acc: 0.9837
#
# Epoch 305/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0577 Acc: 0.9835
#
# Epoch 306/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0464 Acc: 0.9858
#
# Epoch 307/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0521 Acc: 0.9850
#
# Epoch 308/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9837
#
# Epoch 309/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0497 Acc: 0.9852
#
# Epoch 310/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0554 Acc: 0.9843
#
# Epoch 311/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0535 Acc: 0.9835
#
# Epoch 312/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0507 Acc: 0.9848
#
# Epoch 313/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0547 Acc: 0.9833
#
# Epoch 314/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0499 Acc: 0.9845
#
# Epoch 315/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0502 Acc: 0.9850
#
# Epoch 316/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0522 Acc: 0.9837
#
# Epoch 317/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9842
#
# Epoch 318/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0542 Acc: 0.9838
#
# Epoch 319/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9837
#
# Epoch 320/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0505 Acc: 0.9838
#
# Epoch 321/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9853
#
# Epoch 322/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0533 Acc: 0.9833
#
# Epoch 323/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0488 Acc: 0.9848
#
# Epoch 324/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0508 Acc: 0.9853
#
# Epoch 325/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0511 Acc: 0.9843
#
# Epoch 326/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0544 Acc: 0.9837
#
# Epoch 327/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0537 Acc: 0.9837
#
# Epoch 328/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0517 Acc: 0.9835
#
# Epoch 329/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0545 Acc: 0.9830
#
# Epoch 330/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0516 Acc: 0.9848
#
# Epoch 331/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0531 Acc: 0.9842
#
# Epoch 332/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0539 Acc: 0.9835
#
# Epoch 333/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0548 Acc: 0.9848
#
# Epoch 334/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0560 Acc: 0.9825
#
# Epoch 335/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0559 Acc: 0.9830
#
# Epoch 336/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0489 Acc: 0.9862
#
# Epoch 337/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0545 Acc: 0.9842
#
# Epoch 338/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9842
#
# Epoch 339/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0555 Acc: 0.9835
#
# Epoch 340/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0522 Acc: 0.9838
#
# Epoch 341/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0524 Acc: 0.9842
#
# Epoch 342/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0506 Acc: 0.9848
#
# Epoch 343/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9835
#
# Epoch 344/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0498 Acc: 0.9847
#
# Epoch 345/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0488 Acc: 0.9852
#
# Epoch 346/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0506 Acc: 0.9848
#
# Epoch 347/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0564 Acc: 0.9837
#
# Epoch 348/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0608 Acc: 0.9822
#
# Epoch 349/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0583 Acc: 0.9820
#
# Epoch 350/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0526 Acc: 0.9842
#
# Epoch 351/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0501 Acc: 0.9852
#
# Epoch 352/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0569 Acc: 0.9835
#
# Epoch 353/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0581 Acc: 0.9832
#
# Epoch 354/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9837
#
# Epoch 355/499
# ----------
# train Loss: 0.0004 Acc: 0.9998
# val Loss: 0.0496 Acc: 0.9837
#
# Epoch 356/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9848
#
# Epoch 357/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0544 Acc: 0.9833
#
# Epoch 358/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0499 Acc: 0.9858
#
# Epoch 359/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0500 Acc: 0.9858
#
# Epoch 360/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0503 Acc: 0.9843
#
# Epoch 361/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0547 Acc: 0.9833
#
# Epoch 362/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9828
#
# Epoch 363/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0564 Acc: 0.9835
#
# Epoch 364/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0517 Acc: 0.9837
#
# Epoch 365/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0504 Acc: 0.9852
#
# Epoch 366/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0585 Acc: 0.9822
#
# Epoch 367/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0566 Acc: 0.9823
#
# Epoch 368/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0519 Acc: 0.9845
#
# Epoch 369/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0547 Acc: 0.9837
#
# Epoch 370/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9835
#
# Epoch 371/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0536 Acc: 0.9845
#
# Epoch 372/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0528 Acc: 0.9842
#
# Epoch 373/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0526 Acc: 0.9838
#
# Epoch 374/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0522 Acc: 0.9840
#
# Epoch 375/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0511 Acc: 0.9848
#
# Epoch 376/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0568 Acc: 0.9820
#
# Epoch 377/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0547 Acc: 0.9838
#
# Epoch 378/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0507 Acc: 0.9848
#
# Epoch 379/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0537 Acc: 0.9842
#
# Epoch 380/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9838
#
# Epoch 381/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9833
#
# Epoch 382/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9837
#
# Epoch 383/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0497 Acc: 0.9853
#
# Epoch 384/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0518 Acc: 0.9850
#
# Epoch 385/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0551 Acc: 0.9828
#
# Epoch 386/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0541 Acc: 0.9835
#
# Epoch 387/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0533 Acc: 0.9837
#
# Epoch 388/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0534 Acc: 0.9845
#
# Epoch 389/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0544 Acc: 0.9837
#
# Epoch 390/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0526 Acc: 0.9842
#
# Epoch 391/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9835
#
# Epoch 392/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9847
#
# Epoch 393/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9845
#
# Epoch 394/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0491 Acc: 0.9863
#
# Epoch 395/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0527 Acc: 0.9837
#
# Epoch 396/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0589 Acc: 0.9833
#
# Epoch 397/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0506 Acc: 0.9847
#
# Epoch 398/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0583 Acc: 0.9825
#
# Epoch 399/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0516 Acc: 0.9850
#
# Epoch 400/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0553 Acc: 0.9842
#
# Epoch 401/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0538 Acc: 0.9848
#
# Epoch 402/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0473 Acc: 0.9862
#
# Epoch 403/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0573 Acc: 0.9823
#
# Epoch 404/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0576 Acc: 0.9838
#
# Epoch 405/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0521 Acc: 0.9835
#
# Epoch 406/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9828
#
# Epoch 407/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0456 Acc: 0.9868
#
# Epoch 408/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9825
#
# Epoch 409/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0558 Acc: 0.9837
#
# Epoch 410/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0555 Acc: 0.9835
#
# Epoch 411/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9850
#
# Epoch 412/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0583 Acc: 0.9812
#
# Epoch 413/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0508 Acc: 0.9848
#
# Epoch 414/499
# ----------
# train Loss: 0.0002 Acc: 0.9998
# val Loss: 0.0462 Acc: 0.9863
#
# Epoch 415/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0495 Acc: 0.9848
#
# Epoch 416/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0464 Acc: 0.9862
#
# Epoch 417/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0505 Acc: 0.9838
#
# Epoch 418/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0579 Acc: 0.9825
#
# Epoch 419/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0530 Acc: 0.9843
#
# Epoch 420/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0541 Acc: 0.9837
#
# Epoch 421/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0546 Acc: 0.9833
#
# Epoch 422/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0481 Acc: 0.9855
#
# Epoch 423/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0481 Acc: 0.9840
#
# Epoch 424/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0538 Acc: 0.9840
#
# Epoch 425/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0518 Acc: 0.9843
#
# Epoch 426/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0564 Acc: 0.9833
#
# Epoch 427/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9828
#
# Epoch 428/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0503 Acc: 0.9840
#
# Epoch 429/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0505 Acc: 0.9847
#
# Epoch 430/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9837
#
# Epoch 431/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0558 Acc: 0.9823
#
# Epoch 432/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0537 Acc: 0.9843
#
# Epoch 433/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0565 Acc: 0.9840
#
# Epoch 434/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0600 Acc: 0.9822
#
# Epoch 435/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0503 Acc: 0.9845
#
# Epoch 436/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9857
#
# Epoch 437/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9840
#
# Epoch 438/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0483 Acc: 0.9858
#
# Epoch 439/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0517 Acc: 0.9850
#
# Epoch 440/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0562 Acc: 0.9832
#
# Epoch 441/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0530 Acc: 0.9852
#
# Epoch 442/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0469 Acc: 0.9850
#
# Epoch 443/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9832
#
# Epoch 444/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0575 Acc: 0.9833
#
# Epoch 445/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0564 Acc: 0.9832
#
# Epoch 446/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0551 Acc: 0.9830
#
# Epoch 447/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0577 Acc: 0.9813
#
# Epoch 448/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0575 Acc: 0.9823
#
# Epoch 449/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9852
#
# Epoch 450/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0530 Acc: 0.9840
#
# Epoch 451/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0518 Acc: 0.9847
#
# Epoch 452/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9832
#
# Epoch 453/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0585 Acc: 0.9832
#
# Epoch 454/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0496 Acc: 0.9838
#
# Epoch 455/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0524 Acc: 0.9837
#
# Epoch 456/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0538 Acc: 0.9848
#
# Epoch 457/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0529 Acc: 0.9850
#
# Epoch 458/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0581 Acc: 0.9827
#
# Epoch 459/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9843
#
# Epoch 460/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0493 Acc: 0.9847
#
# Epoch 461/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0549 Acc: 0.9843
#
# Epoch 462/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0557 Acc: 0.9833
#
# Epoch 463/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0526 Acc: 0.9832
#
# Epoch 464/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0519 Acc: 0.9852
#
# Epoch 465/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0505 Acc: 0.9853
#
# Epoch 466/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9853
#
# Epoch 467/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0578 Acc: 0.9832
#
# Epoch 468/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0532 Acc: 0.9833
#
# Epoch 469/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0511 Acc: 0.9843
#
# Epoch 470/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9827
#
# Epoch 471/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0574 Acc: 0.9830
#
# Epoch 472/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0570 Acc: 0.9830
#
# Epoch 473/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0514 Acc: 0.9843
#
# Epoch 474/499
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0580 Acc: 0.9828
#
# Epoch 475/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0486 Acc: 0.9843
#
# Epoch 476/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0542 Acc: 0.9832
#
# Epoch 477/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0481 Acc: 0.9842
#
# Epoch 478/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0508 Acc: 0.9850
#
# Epoch 479/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0546 Acc: 0.9828
#
# Epoch 480/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0513 Acc: 0.9847
#
# Epoch 481/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0540 Acc: 0.9848
#
# Epoch 482/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0482 Acc: 0.9852
#
# Epoch 483/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0507 Acc: 0.9842
#
# Epoch 484/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0516 Acc: 0.9847
#
# Epoch 485/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0500 Acc: 0.9853
#
# Epoch 486/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0523 Acc: 0.9853
#
# Epoch 487/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0556 Acc: 0.9840
#
# Epoch 488/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0561 Acc: 0.9840
#
# Epoch 489/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0552 Acc: 0.9828
#
# Epoch 490/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0587 Acc: 0.9835
#
# Epoch 491/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0551 Acc: 0.9838
#
# Epoch 492/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0514 Acc: 0.9843
#
# Epoch 493/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0534 Acc: 0.9838
#
# Epoch 494/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0547 Acc: 0.9823
#
# Epoch 495/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0541 Acc: 0.9842
#
# Epoch 496/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0512 Acc: 0.9853
#
# Epoch 497/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0572 Acc: 0.9832
#
# Epoch 498/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0522 Acc: 0.9842
#
# Epoch 499/499
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0499 Acc: 0.9853
#
# Training complete in 413m 50s
# Best val Acc: 0.986833

# %%
torch.save(model_ft.state_dict(), 'resnet18_tongji_unfreezed.pt')

# %%
epochs = range(0,500)
plt.plot(epochs, train_lss, 'g', label='Training loss')
plt.plot(epochs, val_lss, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig('loss.png')

# %%
epochs = range(0,500)
plt.plot(epochs, train_acc, 'g', label='Training acc.')
plt.plot(epochs, val_acc, 'b', label='validation acc.')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
plt.savefig('acc.png')
